# %%
import matplotlib.pyplot as plt
from pathlib import Path 
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
import seaborn as sns
df1 = pd.read_csv('SLEEP_ACTIGRAPHY_MODIFIED.CSV')
df2 = pd.read_csv('V1F.CSV')

# Specify the columns of interest
columns_of_interest = ['PublicID','V1FA02a','V1FA02b', 'V1FA03', 'V1FA04', 'V1FB01', 'V1FB05','V1FE03', 'V1FE04' , 'V1FF01b', 'V1FF01c']
columns_of_interest2 = ['PublicID', 'rest_dur_avg_all_Mod', 'rest_sleeptime_avg_all_Mod', 'sleep_dur_avg_all_Mod', 'sleep_sleeptime_avg_all_Mod', 'sleep_Frag_avg_all_Mod', 'sleep_WASO_avg_all_Mod', 'sleep_SE_avg_all_Mod', 'rest_sleeptime_avg_wkday_Mod']  

# Extract these columns
df2_interest = df2[columns_of_interest]
df1_interest = df1[columns_of_interest2]
# Display the DataFrame
print(df2_interest)

# Use Seaborn's pairplot function to visualize relationships between variables
sns.pairplot(df2_interest)
plt.show()
    
print(df1_interest)
sns.pairplot(df1_interest)
plt.show()
# Out:
#     PublicID V1FA02a V1FA02b V1FA03 V1FA04  V1FB01  V1FB05  V1FE03  V1FE04  \
# 0     00021O       7       8     30     15     2.0     1.0     3.0     2.0
# 1     00034F       6       6     60     20     4.0     1.0     3.0     2.0
# 2     00049P       8      10     60     60     5.0     3.0     3.0     3.0
# 3     00060E       9       9     30     15     1.0     2.0     3.0     4.0
# 4     00075O       6       7     30     60     1.0     1.0     1.0     1.0
# ..       ...     ...     ...    ...    ...     ...     ...     ...     ...
# 854   17209B       8       8     15      5     1.0     1.0     4.0     4.0
# 855   17229S       8       9      5      5     1.0     1.0     3.0     3.0
# 856   17275L       9       9     10     10     2.0     1.0     4.0     1.0
# 857   17289A       D       D      5     10     3.0     1.0     5.0     5.0
# 858   17307B       6       6     60    120     5.0     1.0     1.0     1.0
#
#     V1FF01b V1FF01c
# 0         2       2
# 1         2       2
# ...
