# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns
from pathlib import Path 

# Percentage of individuals in each type physical activity

# # of individuals in each activity

#Distribution of amount of time in exercise, time not exercise. 

#3 variables: 
#how many days were they active for 30 minutes or more, 

#How many days were they physically active at all

#Total number of minutes of exercise in a week. 

# Set matplotlib to inline
# %matplotlib inline

# Load data
df1 = pd.read_csv('V2A.CSV')
df2 = pd.read_csv('V3A.CSV')

# Merge data
df = pd.merge(df1, df2, on="PublicID")

df['V2AJ01a_SP'] = df['V2AJ01a_SP'].str.lower()

# Count the occurrences of each activity
activity_counts = df['V2AJ01a_SP'].value_counts()

# Calculate the percentage of individuals doing each activity
activity_percentages = activity_counts / activity_counts.sum() * 100

# Plot the percentages as a bar chart
activity_percentages.plot(kind='bar')

# Add labels and title to the plot
plt.xlabel('Activity')
plt.ylabel('Percentage')
plt.title('Percentage of Individuals Doing Each Activity')

# Show the plot
plt.show()

# All possible columns of interest
'''columns_of_interest = [
    'V2AJ01',
    'V2AJ01a_SP',
    'V2AJ01a',
    'V2AJ01a1',
    'V2AJ01a2',
    'V2AJ01a3',
    'V2AJ02',
    'V2AJ02a_SP',
    'V2AJ02a',
    'V2AJ02a1',
    'V2AJ02a2',
    'V2AJ02a3',
    'V2AJ03',
    'V2AJ03a_SP',
    'V2AJ03a',
    'V2AJ03a1',
    'V2AJ03a2',
    'V2AJ03a3',
    'V3AH01',
    'V3AH01a',
    'V3AH01a_SP',
    'V3AH01a1',
    'V3AH01a2',
    'V3AH01a3',
    'V3AH02',
    'V3AH02a',
    'V3AH02a_SP',
    'V3AH02a1',
    'V3AH02a2',
    'V3AH02a3',
    'V3AH03',
    'V3AH03a',
    'V3AH03a_SP',
    'V3AH03a1',
    'V3AH03a2',
    'V3AH03a3'
]
'''
# Out:
# /var/folders/pw/xkpd454x6_ddjhgkzcvrngc40000gn/T/ipykernel_6673/3472441065.py:26: DtypeWarning: Columns (8,23,30,38,40,49,70,71,72,73,74,75,78,93,100,109,111,112,120,142,148,149,150,151,152,154,155,156,159,161,162,163,164,165,166,168,169,173,174,175,176,177,178,180,181,258,259,260,261,262,266,267,268,269,284,295,300,301,307,308) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('V2A.CSV')
# /var/folders/pw/xkpd454x6_ddjhgkzcvrngc40000gn/T/ipykernel_6673/3472441065.py:27: DtypeWarning: Columns (7,22,51,52,53,54,55,57,58,59,60,62,63,64,65,66,67,68,71,72,73,74,89,103,109,116) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('V3A.CSV')
# ...
