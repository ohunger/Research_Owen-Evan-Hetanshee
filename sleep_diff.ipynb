# %%
import matplotlib.pyplot as plt
from pathlib import Path 
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
import seaborn as sns

# Load the CSV files
df1 = pd.read_csv('SLEEP_ACTIGRAPHY.CSV')
df2 = pd.read_csv('SLEEP_ACTIGRAPHY_MODIFIED.CSV')

# Merge the dataframes on 'public_id'
df = df1.merge(df2, how='outer', on='PublicID', suffixes=('', '_Mod'))

# List of columns of interest
columns_of_interest = ['rest_dur_avg_all', 'rest_sleeptime_avg_all', 'sleep_dur_avg_all', 'sleep_sleeptime_avg_all', 'sleep_Frag_avg_all', 'sleep_WASO_avg_all', 'sleep_SE_avg_all', 'rest_sleeptime_avg_wkday']  # replace these with your actual column names

# Iterate over each column of interest
for original_column in columns_of_interest:
    column = original_column + '_Mod'
    
    # Check if the column is present in both dataframes
    if column in df.columns and original_column in df.columns:
        # Create a difference column
        df[f'{original_column}_DIFF'] = df[column] - df[original_column]
        
        # Plot the differences
        plt.figure(figsize=(10, 5))
        plt.hist(df[f'{original_column}_DIFF'].dropna(), bins=30, alpha=0.5, label='Difference', color='r')
        plt.title(f'Difference in {original_column}')
        plt.xlabel('Difference')
        plt.ylabel('Frequency')
        plt.axvline(0, color='k', linestyle='--')  # Add vertical line at x=0
        plt.legend()
        plt.show()

        # Find rows where the difference is less than zero
        df_less_than_zero = df[df[f'{original_column}_DIFF'] != 0]

        # If there are any such rows, print the Public IDs
        if not df_less_than_zero.empty:
            print("Public IDs where difference in {} is less than zero:".format(original_column))
            print(df_less_than_zero)
            
    #The output of the code provided is a set of histograms, 
    #each displaying the frequency distribution of the differences between pairs of corresponding columns in the two dataframes. 
    #Here's how to interpret these histograms and the data:
    #If the value in 'column_MOD' is greater, the difference will be positive, and if the value in 'column' is greater, the difference will be negative.
    #If the values are the same in both columns, the difference will be zero.
# Out:
# /var/folders/pw/xkpd454x6_ddjhgkzcvrngc40000gn/T/ipykernel_45471/4014030322.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{original_column}_DIFF'] = df[column] - df[original_column]
# Public IDs where difference in rest_dur_avg_all is less than zero:
#     PublicID Actigraphy_PublicID  DateofStudy_INT AnalysisVersion  \
# 79    01972C              01972C             -139           1.2.3
# 236   05707B              05707B             -144           1.2.5
# 444   11818G              11818G             -136           1.2.3
# 559   14856G              14856G             -138           1.2.3
# 609   15977M              15977M             -154           1.2.4
#
#      NumValidDays  NumValidWeekdays  NumValidWeekends  NumValidWorkdays  \
# ...
